# %% [markdown]
# <a href="https://colab.research.google.com/github/Michael-Holland-Dev/CS180/blob/main/data_science_labs/data_science_lab_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BYU CS 180 Lab 12

# %%
# Dependencies for the lab
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
import pandas as pd
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm
# Out:
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,

# %% [markdown]
# ## Introduction:
# In this lab you will fit regression models on multiple datasets.

# %% [markdown]
# ## Exercise 1: Synthetic Data
# First we will fit a regression model to multiple variants of a synthetic dataset. In each case, we know the true parameters (slope and intercept) and we will vary the noise of the data. Execute the following code to generate the data:

# %%
import numpy as np

w_0_true = -2.5 # this is the TRUE intercept
w_1_true = 0.1 # this is the TRUE slope

def f_x(x, w_0, w_1, sig):
  n = len(x)
  y = w_1*x + w_0 + np.random.normal(0, sig, n)
  return y

x = np.arange(0, 100)


y_1 = f_x(x, w_0_true, w_1_true, sig=0.5) # standard deviation = 0.5
y_2 = f_x(x, w_0_true, w_1_true, sig=1.5) # standard deviation = 1.5
y_3 = f_x(x, w_0_true, w_1_true, sig=5.0) # standard deviation = 5
y_4 = f_x(x, w_0_true, w_1_true, sig=10.0) # standard deviation = 10

# %% [markdown]
# ### Question 1a:
# For each of the four datasets we generated do the following:
#
# * Plot a scatter plot of `x` and `y_i` (e.g, `x` and `y_2`)
#
# * Fit a [linear regression model](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html) using sklearn (sklearn.linear_model.LinearRegression )
#
#   * Make sure `fit_intercept` is set to `True`
#
#   * hint: sklearn expects the features to be two-dimensional. You many need to use the following code to reshape your `x` array when training:
#
# ```
#   reg = LinearRegression(fit_intercept=True)
#   reg.fit(x.reshape(-1, 1), y) # reshape x to be two-dimensional
# ```
# * Print the estimated coefficients:
#
#   * These can be accessed with the `coef_` and `intercept_` attributes on the regression object
#
# * Plot the regression line on the scatter plots of `x` and `y`
#
# Comment on how well the regression model approximates the data

# %%
from sklearn.linear_model import LinearRegression
# Write your code for question 1a here

reg = LinearRegression(fit_intercept=True)
plt.scatter(x,y_1)
reg.fit(x.reshape(-1, 1), y_1) # reshape x to be two-dimensional
plt.plot(reg.coef_*x+reg.intercept_)
print(reg.coef_, reg.intercept_)
plt.show()

plt.scatter(x,y_2)
reg.fit(x.reshape(-1, 1), y_2) # reshape x to be two-dimensional
plt.plot(reg.coef_*x+reg.intercept_)
print(reg.coef_, reg.intercept_)
plt.show()

plt.scatter(x,y_3)
reg.fit(x.reshape(-1, 1), y_3) # reshape x to be two-dimensional
plt.plot(reg.coef_*x+reg.intercept_)
print(reg.coef_, reg.intercept_)
plt.show()

plt.scatter(x,y_4)
reg.fit(x.reshape(-1, 1), y_4) # reshape x to be two-dimensional
plt.plot(reg.coef_*x+reg.intercept_)
print(reg.coef_, reg.intercept_)
plt.show()
# Out:
# [0.10225179] -2.5598849288662153
# [0.10615721] -2.7808127642171665
# [0.12834062] -4.975149925298397
# [0.13440672] -4.009920731211608

# %% [markdown]
# ### Question 1b:
#
# What do you observe as we add noise to our generated dataset? How well are we able to recover the true parameters, `w_0_true` and `w_1_true` from the data as noise increases?

# %% [markdown]
# iT'S GETTING WORSE!

# %% [markdown]
# # Exercise 2
# Read the California Housing Data from the `sample_data` on every collab instance:

# %%
import pandas as pd
train = pd.read_csv("sample_data/california_housing_train.csv")
test = pd.read_csv("sample_data/california_housing_test.csv")

# %% [markdown]
# This dataset contains features on census tracts in California in the early 1990’s. The target is the variable `median_house_value` of each census tract.

# %% [markdown]
# ### Exercise 2a:
# Plot a [scatter_plot matrix](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.plotting.scatter_matrix.html) using the training data. You may need to tune the `fig_size` argument to make the figure larger.

# %%
# Enter your code to plot the scatter_plot matrix here.
pd.plotting.scatter_matrix(train, alpha=0.2, figsize= (20,20))
plt.show()

# %% [markdown]
# What variables appear to be correlated with `median_house_value`?

# %% [markdown]
# median_income

# %% [markdown]
# What variables are not correlated with `median_house_value`?

# %% [markdown]
# housing_median_age

# %% [markdown]
# What features appear to be correlated with each other?

# %% [markdown]
# total_bedrooms and house holds

# %% [markdown]
# ### Exercise 2b
# Fit a linear regression model using `sklearn`.
# * Fit a few different models (each with different features).
# * Evaluate the [mean_squared_error](https://scikit-learn.org/stable/modules/model_evaluation.html#mean-squared-error) of your models with both the training and test set.

# %%
from sklearn.metrics import mean_squared_error
reg = LinearRegression(fit_intercept=True)
reg.fit(train[['housing_median_age', 'population']],train['median_house_value']) # reshape x to be two-dimensional
print(mean_squared_error(test['median_house_value'], reg.predict(test[['housing_median_age', 'population']])))

reg.fit(train[['latitude', 'total_rooms']],train['households']) # reshape x to be two-dimensional
print(mean_squared_error(test['households'], reg.predict(test[['latitude', 'total_rooms']])))
# Out:
# 12689526451.065243
# 22072.34191004614

# %% [markdown]
# What did you observe? Which model yields the lowest test error?

# %% [markdown]
# I got latitude and total_rooms lower

# %% [markdown]
# ### Exercise 2c
# Fit a linear regression using the `statsmodels` api.
# * Print the model output using `print(results.summary())`

# %%
import statsmodels.api as sm
#Enter your code for exercise 2c here.
x = train[['housing_median_age', 'population']]
y = train['median_house_value']
x = sm.add_constant(x)
model = sm.OLS(y, x).fit() # reshape x to be two-dimensional
print(model.summary())

x = train[['latitude', 'total_rooms']]
y = train['households']
x = sm.add_constant(x)
model = sm.OLS(y, x).fit() # reshape x to be two-dimensional
print(model.summary())

x = train[['longitude', 'median_house_value']]
y = train['median_income']
x = sm.add_constant(x)
model = sm.OLS(y, x).fit() # reshape x to be two-dimensional
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     median_house_value   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     98.11
# Date:                Thu, 30 Mar 2023   Prob (F-statistic):           4.32e-43
# Time:                        18:44:17   Log-Likelihood:            -2.2226e+05
# No. Observations:               17000   AIC:                         4.445e+05
# Df Residuals:                   16997   BIC:                         4.446e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               1.783e+05   2823.421     63.138      0.000    1.73e+05    1.84e+05
# housing_median_age   994.9020     73.569     13.523      0.000     850.699    1139.105
# population             0.4140      0.807      0.513      0.608      -1.167       1.995
# ==============================================================================
# Omnibus:                     1853.233   Durbin-Watson:                   0.589
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2520.455
# Skew:                           0.934   Prob(JB):                         0.00
# Kurtosis:                       3.260   Cond. No.                     5.85e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.85e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             households   R-squared:                       0.846
# Model:                            OLS   Adj. R-squared:                  0.846
# Method:                 Least Squares   F-statistic:                 4.674e+04
# Date:                Thu, 30 Mar 2023   Prob (F-statistic):               0.00
# Time:                        18:44:17   Log-Likelihood:            -1.0940e+05
# No. Observations:               17000   AIC:                         2.188e+05
# Df Residuals:                   16997   BIC:                         2.188e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         325.4458     19.438     16.743      0.000     287.346     363.545
# latitude       -7.0755      0.542    -13.062      0.000      -8.137      -6.014
# total_rooms     0.1618      0.001    304.718      0.000       0.161       0.163
# ==============================================================================
# Omnibus:                     5839.567   Durbin-Watson:                   1.341
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           233030.700
# Skew:                           0.954   Prob(JB):                         0.00
# Kurtosis:                      21.037   Cond. No.                     5.76e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.76e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          median_income   R-squared:                       0.479
# Model:                            OLS   Adj. R-squared:                  0.479
# Method:                 Least Squares   F-statistic:                     7811.
# Date:                Thu, 30 Mar 2023   Prob (F-statistic):               0.00
# Time:                        18:44:17   Log-Likelihood:                -29565.
# No. Observations:               17000   AIC:                         5.914e+04
# Df Residuals:                   16997   BIC:                         5.916e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  3.3042      0.630      5.244      0.000       2.069       4.539
# longitude              0.0149      0.005      2.827      0.005       0.005       0.025
# median_house_value  1.139e-05   9.12e-08    124.958      0.000    1.12e-05    1.16e-05
# ==============================================================================
# Omnibus:                     2518.733   Durbin-Watson:                   1.192
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13906.661
# Skew:                           0.599   Prob(JB):                         0.00
# Kurtosis:                       7.266   Cond. No.                     1.42e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.42e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   x = pd.concat(x[::order], 1)

# %% [markdown]
# Comment on which features appear to have the strongest relationship with `median_house_value`?

# %% [markdown]
# median_income

# %% [markdown]
# Write a sentence interpreting the coefficient for `median_income`.

# %% [markdown]
# when median_income increases by 1, median_house_value prediction increases by 45840 units
