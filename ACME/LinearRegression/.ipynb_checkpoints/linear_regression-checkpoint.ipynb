# %% [markdown]
# ## Linear Regression
# ### Name: Rebecah Kwak
# ### Class: vol3
# ### Section: Bryce Section
# ### Date: Week 9

# %%
import numpy as np
import pandas as pd
import time
import statsmodels.api as sm
from sklearn import linear_model
from itertools import combinations
from matplotlib import pyplot as plt
import time

# %% [markdown]
# ## Problem 1
# Write a function that takes as input $X$ and **y** as defined on page 1. Call this function **ols**. This function should return the least squares estimator for $\beta$ as a numpy array.

# %%
def ols(X, y):
    """
    Solves for the least squares estimator.
    Add a column of 1s to X.
    Parameters:
        X: n x d numpyarray
        y: n x 1 numpyarray
    Returns:
        beta: d x 1 numpyarray
    """
    #adding a column of ones to X to account for B0
    x0 = np.ones_like(X)
    Xnew = np.vstack((X,x0)).T
    #putting values to make B
    B = np.linalg.inv(Xnew.T@Xnew)@Xnew.T@y
    
    return B

# %% [markdown]
# ## Problem 2
# Find the least squares estimator for $\beta$ using this random data.
# Produce a plot showing the random data and the line of best fit determined by the least squares estimator for $\beta$.
# Your plot should include a title, axis labels, and a legend.

# %%
n = 100 # Number of points to generate
X = np.arange(100) # The input X for the function ols
eps = np.random.uniform(-10,10, size=(100,)) # Noise to generate random y ← coordinates
y = .3*X + 3 + eps # The input y for the function ols

#getting the slope and the y-intercept
a, b = ols(X,y)

#plotting
plt.plot(X, X*a+b,color = 'red')
plt.scatter(X,y, color = 'blue')
plt.xlabel("x")
plt.ylabel("y")
plt.title("random data and the line of best fit with B using ols")
plt.show()

# %% [markdown]
# ## Problem 3
# Write a function that finds the least squares estimator for rank-deficient models using the SVD.
# The function should still take $X$ and **y** as inputs. Call the function **svd_ols** and return the least squares estimator for $\beta$ as a numpy array.

# %%
def svd_ols(X, y):
    """
    Solves for the least squares estimator using the SVD.
    Add a column of 1s to X.
    Parameters:
        X: n x d numpyarray
        y: n x 1 numpyarray
    Returns:
        beta: d x 1 numpy array
    """
    #adding a column of ones to X to account for B0
    x0 = [1]*np.shape(X)[0]
    Xnew = np.column_stack((x0,X))

    U,s,V_T = np.linalg.svd(Xnew,full_matrices = False)
    #putting values to make B
    B = V_T.T@np.diag(1/s)@U.T@y

    return B

# %% [markdown]
# ## Problem 4
# Use your function **svd_ols** to find the least squares estimator for a cubic polynomial.
# Create a plot that shows a scatter plot of the data and a curve using the least squares estimator.
# Your plot should include a title, axis labels, and a legend.

# %%
x = np.linspace(-4, 2, 500)
y = x**3 + 3*x**2 - x - 3.5
eps = np.random.normal(0, 3, len(y)) # Create noise
y += eps # Add noise to randomize data

#getting the slope and the y-intercept
X = np.vander(x, 4, increasing = True)
T = svd_ols(X[:,1:],y)

#plotting
plt.scatter(x,y, color = 'blue',s=.25)
plt.plot(x, X@T)
plt.xlabel("x")
plt.ylabel("y")
plt.title("random data and the line of best fit with B using svd_ols")
plt.show()

# %% [markdown]
# ## Problem 5
# The file **realestate.csv** contains transaction data from 2012-2013.
# It has columns for transaction data, house age, distance to nearest MRT station, number of convenience stores, latitude, longitude, and house price of unit area.
# Each row in the array is a separate measurement.
#
# Find the combination of variables that builds the model with the best $R^2$ value when predicting **house price of unit area**. Use statsmodels to build each model and calculate $R^2$. Use **statsmodels** to build each model and calculate $R^2$. Using the same combination of variables, time the methods **ols**, **svd_ols**, and **statsmodels** . Return a list with the first element being a tuple of times for each method and the second element being the best $R^2$ value from the first part of the problem.

# %%
def problem5():
    """
    Find the best R2 value using statsmodels.
    Then time ols, svd_ols, and statsmodlels.
    Returns:
        list(): a tuple of times and the best R2 value
    """
    data = pd.read_csv("realestate.csv") # Read in data as pandas dataframe
    y = data["Y house price of unit area"] # Extract dependent variable
    titles = ["X1 transaction date", "X2 house age", "X3 distance to the nearest MRT station", "X4 number of convenience stores", "X5 latitude", "X6 longitude"]

    temp_X = data[titles] # Extract independent variables
    
    R_2 = []
    for i in range(1,len(titles)+1):
        for comb in combinations(titles,i):
            model = sm.OLS(y,sm.add_constant(temp_X[list(comb)])).fit()
            R_2.append(model.rsquared)
            
    R_2 = max(R_2)
    
    a = time.time()
    #svd
    ols(temp_X, y)
    b = time.time()
 
    #ols
    svd_ols(X,R_2)
    c = time.time()
    #stats
    sm.OLS(R_2,X).fit()
    d = time.time()

    return ([b-a,c-b,d-c],R_2)

# %%
problem5()
# Out:
#      const  X1 transaction date
# 0      1.0             2012.917
# 1      1.0             2012.917
# 2      1.0             2013.583
# 3      1.0             2013.500
# 4      1.0             2012.833
# ..     ...                  ...
# 409    1.0             2013.000
# 410    1.0             2012.667
# 411    1.0             2013.250
# 412    1.0             2013.000
# 413    1.0             2013.500
#
# [414 rows x 2 columns]
#      const  X2 house age
# 0      1.0          32.0
# 1      1.0          19.5
# 2      1.0          13.3
# 3      1.0          13.3
# 4      1.0           5.0
# ..     ...           ...
# 409    1.0          13.7
# 410    1.0           5.6
# 411    1.0          18.8
# 412    1.0           8.1
# 413    1.0           6.5
#
# [414 rows x 2 columns]
#      const  X3 distance to the nearest MRT station
# 0      1.0                                84.87882
# 1      1.0                               306.59470
# 2      1.0                               561.98450
# 3      1.0                               561.98450
# 4      1.0                               390.56840
# ..     ...                                     ...
# 409    1.0                              4082.01500
# 410    1.0                                90.45606
# 411    1.0                               390.96960
# 412    1.0                               104.81010
# 413    1.0                                90.45606
#
# [414 rows x 2 columns]
#      const  X4 number of convenience stores
# 0      1.0                               10
# 1      1.0                                9
# 2      1.0                                5
# 3      1.0                                5
# 4      1.0                                5
# ..     ...                              ...
# 409    1.0                                0
# 410    1.0                                9
# 411    1.0                                7
# 412    1.0                                5
# 413    1.0                                9
#
# [414 rows x 2 columns]
#      const  X5 latitude
# 0      1.0     24.98298
# 1      1.0     24.98034
# 2      1.0     24.98746
# 3      1.0     24.98746
# 4      1.0     24.97937
# ..     ...          ...
# 409    1.0     24.94155
# 410    1.0     24.97433
# 411    1.0     24.97923
# 412    1.0     24.96674
# 413    1.0     24.97433
#
# [414 rows x 2 columns]
#      const  X6 longitude
# 0      1.0     121.54024
# 1      1.0     121.53951
# 2      1.0     121.54391
# 3      1.0     121.54391
# 4      1.0     121.54245
# ..     ...           ...
# 409    1.0     121.50381
# 410    1.0     121.54310
# 411    1.0     121.53986
# 412    1.0     121.54067
# 413    1.0     121.54310
#
# [414 rows x 2 columns]
#      const  X1 transaction date  X2 house age
# 0      1.0             2012.917          32.0
# 1      1.0             2012.917          19.5
# 2      1.0             2013.583          13.3
# 3      1.0             2013.500          13.3
# 4      1.0             2012.833           5.0
# ..     ...                  ...           ...
# 409    1.0             2013.000          13.7
# 410    1.0             2012.667           5.6
# 411    1.0             2013.250          18.8
# 412    1.0             2013.000           8.1
# 413    1.0             2013.500           6.5
#
# [414 rows x 3 columns]
#      const  X1 transaction date  X3 distance to the nearest MRT station
# 0      1.0             2012.917                                84.87882
# 1      1.0             2012.917                               306.59470
# 2      1.0             2013.583                               561.98450
# 3      1.0             2013.500                               561.98450
# 4      1.0             2012.833                               390.56840
# ..     ...                  ...                                     ...
# 409    1.0             2013.000                              4082.01500
# 410    1.0             2012.667                                90.45606
# 411    1.0             2013.250                               390.96960
# 412    1.0             2013.000                               104.81010
# 413    1.0             2013.500                                90.45606
#
# [414 rows x 3 columns]
#      const  X1 transaction date  X4 number of convenience stores
# 0      1.0             2012.917                               10
# 1      1.0             2012.917                                9
# 2      1.0             2013.583                                5
# 3      1.0             2013.500                                5
# 4      1.0             2012.833                                5
# ..     ...                  ...                              ...
# 409    1.0             2013.000                                0
# 410    1.0             2012.667                                9
# 411    1.0             2013.250                                7
# 412    1.0             2013.000                                5
# 413    1.0             2013.500                                9
#
# [414 rows x 3 columns]
#      const  X1 transaction date  X5 latitude
# 0      1.0             2012.917     24.98298
# 1      1.0             2012.917     24.98034
# 2      1.0             2013.583     24.98746
# 3      1.0             2013.500     24.98746
# 4      1.0             2012.833     24.97937
# ..     ...                  ...          ...
# 409    1.0             2013.000     24.94155
# 410    1.0             2012.667     24.97433
# 411    1.0             2013.250     24.97923
# 412    1.0             2013.000     24.96674
# 413    1.0             2013.500     24.97433
#
# [414 rows x 3 columns]
#      const  X1 transaction date  X6 longitude
# 0      1.0             2012.917     121.54024
# 1      1.0             2012.917     121.53951
# 2      1.0             2013.583     121.54391
# 3      1.0             2013.500     121.54391
# 4      1.0             2012.833     121.54245
# ..     ...                  ...           ...
# 409    1.0             2013.000     121.50381
# 410    1.0             2012.667     121.54310
# 411    1.0             2013.250     121.53986
# 412    1.0             2013.000     121.54067
# 413    1.0             2013.500     121.54310
#
# [414 rows x 3 columns]
#      const  X2 house age  X3 distance to the nearest MRT station
# 0      1.0          32.0                                84.87882
# 1      1.0          19.5                               306.59470
# 2      1.0          13.3                               561.98450
# 3      1.0          13.3                               561.98450
# 4      1.0           5.0                               390.56840
# ..     ...           ...                                     ...
# 409    1.0          13.7                              4082.01500
# 410    1.0           5.6                                90.45606
# 411    1.0          18.8                               390.96960
# 412    1.0           8.1                               104.81010
# 413    1.0           6.5                                90.45606
#
# [414 rows x 3 columns]
#      const  X2 house age  X4 number of convenience stores
# 0      1.0          32.0                               10
# 1      1.0          19.5                                9
# 2      1.0          13.3                                5
# 3      1.0          13.3                                5
# 4      1.0           5.0                                5
# ..     ...           ...                              ...
# 409    1.0          13.7                                0
# 410    1.0           5.6                                9
# 411    1.0          18.8                                7
# 412    1.0           8.1                                5
# 413    1.0           6.5                                9
#
# [414 rows x 3 columns]
#      const  X2 house age  X5 latitude
# 0      1.0          32.0     24.98298
# 1      1.0          19.5     24.98034
# 2      1.0          13.3     24.98746
# 3      1.0          13.3     24.98746
# 4      1.0           5.0     24.97937
# ..     ...           ...          ...
# 409    1.0          13.7     24.94155
# 410    1.0           5.6     24.97433
# 411    1.0          18.8     24.97923
# 412    1.0           8.1     24.96674
# 413    1.0           6.5     24.97433
#
# [414 rows x 3 columns]
#      const  X2 house age  X6 longitude
# 0      1.0          32.0     121.54024
# 1      1.0          19.5     121.53951
# 2      1.0          13.3     121.54391
# 3      1.0          13.3     121.54391
# 4      1.0           5.0     121.54245
# ..     ...           ...           ...
# 409    1.0          13.7     121.50381
# 410    1.0           5.6     121.54310
# 411    1.0          18.8     121.53986
# 412    1.0           8.1     121.54067
# 413    1.0           6.5     121.54310
#
# [414 rows x 3 columns]
#      const  X3 distance to the nearest MRT station  \
# 0      1.0                                84.87882
# 1      1.0                               306.59470
# 2      1.0                               561.98450
# 3      1.0                               561.98450
# 4      1.0                               390.56840
# ..     ...                                     ...
# 409    1.0                              4082.01500
# 410    1.0                                90.45606
# 411    1.0                               390.96960
# 412    1.0                               104.81010
# 413    1.0                                90.45606
#
#      X4 number of convenience stores
# 0                                 10
# 1                                  9
# 2                                  5
# 3                                  5
# 4                                  5
# ..                               ...
# 409                                0
# 410                                9
# 411                                7
# 412                                5
# 413                                9
#
# [414 rows x 3 columns]
#      const  X3 distance to the nearest MRT station  X5 latitude
# 0      1.0                                84.87882     24.98298
# 1      1.0                               306.59470     24.98034
# 2      1.0                               561.98450     24.98746
# 3      1.0                               561.98450     24.98746
# 4      1.0                               390.56840     24.97937
# ..     ...                                     ...          ...
# 409    1.0                              4082.01500     24.94155
# 410    1.0                                90.45606     24.97433
# 411    1.0                               390.96960     24.97923
# 412    1.0                               104.81010     24.96674
# 413    1.0                                90.45606     24.97433
#
# [414 rows x 3 columns]
#      const  X3 distance to the nearest MRT station  X6 longitude
# 0      1.0                                84.87882     121.54024
# 1      1.0                               306.59470     121.53951
# 2      1.0                               561.98450     121.54391
# 3      1.0                               561.98450     121.54391
# 4      1.0                               390.56840     121.54245
# ..     ...                                     ...           ...
# 409    1.0                              4082.01500     121.50381
# 410    1.0                                90.45606     121.54310
# 411    1.0                               390.96960     121.53986
# 412    1.0                               104.81010     121.54067
# 413    1.0                                90.45606     121.54310
#
# [414 rows x 3 columns]
#      const  X4 number of convenience stores  X5 latitude
# 0      1.0                               10     24.98298
# 1      1.0                                9     24.98034
# 2      1.0                                5     24.98746
# 3      1.0                                5     24.98746
# 4      1.0                                5     24.97937
# ..     ...                              ...          ...
# 409    1.0                                0     24.94155
# 410    1.0                                9     24.97433
# 411    1.0                                7     24.97923
# 412    1.0                                5     24.96674
# 413    1.0                                9     24.97433
#
# [414 rows x 3 columns]
#      const  X4 number of convenience stores  X6 longitude
# 0      1.0                               10     121.54024
# 1      1.0                                9     121.53951
# 2      1.0                                5     121.54391
# 3      1.0                                5     121.54391
# 4      1.0                                5     121.54245
# ..     ...                              ...           ...
# 409    1.0                                0     121.50381
# 410    1.0                                9     121.54310
# 411    1.0                                7     121.53986
# 412    1.0                                5     121.54067
# 413    1.0                                9     121.54310
#
# [414 rows x 3 columns]
#      const  X5 latitude  X6 longitude
# 0      1.0     24.98298     121.54024
# 1      1.0     24.98034     121.53951
# 2      1.0     24.98746     121.54391
# 3      1.0     24.98746     121.54391
# 4      1.0     24.97937     121.54245
# ..     ...          ...           ...
# 409    1.0     24.94155     121.50381
# 410    1.0     24.97433     121.54310
# 411    1.0     24.97923     121.53986
# 412    1.0     24.96674     121.54067
# 413    1.0     24.97433     121.54310
#
# [414 rows x 3 columns]
#      const  X1 transaction date  X2 house age  \
# 0      1.0             2012.917          32.0
# 1      1.0             2012.917          19.5
# 2      1.0             2013.583          13.3
# 3      1.0             2013.500          13.3
# 4      1.0             2012.833           5.0
# ..     ...                  ...           ...
# 409    1.0             2013.000          13.7
# 410    1.0             2012.667           5.6
# 411    1.0             2013.250          18.8
# 412    1.0             2013.000           8.1
# 413    1.0             2013.500           6.5
#
#      X3 distance to the nearest MRT station
# 0                                  84.87882
# 1                                 306.59470
# 2                                 561.98450
# 3                                 561.98450
# 4                                 390.56840
# ..                                      ...
# 409                              4082.01500
# 410                                90.45606
# 411                               390.96960
# 412                               104.81010
# 413                                90.45606
#
# [414 rows x 4 columns]
#      const  X1 transaction date  X2 house age  X4 number of convenience stores
# 0      1.0             2012.917          32.0                               10
# 1      1.0             2012.917          19.5                                9
# 2      1.0             2013.583          13.3                                5
# 3      1.0             2013.500          13.3                                5
# 4      1.0             2012.833           5.0                                5
# ..     ...                  ...           ...                              ...
# 409    1.0             2013.000          13.7                                0
# 410    1.0             2012.667           5.6                                9
# 411    1.0             2013.250          18.8                                7
# 412    1.0             2013.000           8.1                                5
# 413    1.0             2013.500           6.5                                9
#
# [414 rows x 4 columns]
#      const  X1 transaction date  X2 house age  X5 latitude
# 0      1.0             2012.917          32.0     24.98298
# 1      1.0             2012.917          19.5     24.98034
# 2      1.0             2013.583          13.3     24.98746
# 3      1.0             2013.500          13.3     24.98746
# 4      1.0             2012.833           5.0     24.97937
# ..     ...                  ...           ...          ...
# 409    1.0             2013.000          13.7     24.94155
# 410    1.0             2012.667           5.6     24.97433
# 411    1.0             2013.250          18.8     24.97923
# 412    1.0             2013.000           8.1     24.96674
# 413    1.0             2013.500           6.5     24.97433
#
# [414 rows x 4 columns]
#      const  X1 transaction date  X2 house age  X6 longitude
# 0      1.0             2012.917          32.0     121.54024
# 1      1.0             2012.917          19.5     121.53951
# 2      1.0             2013.583          13.3     121.54391
# 3      1.0             2013.500          13.3     121.54391
# 4      1.0             2012.833           5.0     121.54245
# ..     ...                  ...           ...           ...
# 409    1.0             2013.000          13.7     121.50381
# 410    1.0             2012.667           5.6     121.54310
# 411    1.0             2013.250          18.8     121.53986
# 412    1.0             2013.000           8.1     121.54067
# 413    1.0             2013.500           6.5     121.54310
#
# [414 rows x 4 columns]
#      const  X1 transaction date  X3 distance to the nearest MRT station  \
# 0      1.0             2012.917                                84.87882
# 1      1.0             2012.917                               306.59470
# 2      1.0             2013.583                               561.98450
# 3      1.0             2013.500                               561.98450
# 4      1.0             2012.833                               390.56840
# ..     ...                  ...                                     ...
# 409    1.0             2013.000                              4082.01500
# 410    1.0             2012.667                                90.45606
# 411    1.0             2013.250                               390.96960
# 412    1.0             2013.000                               104.81010
# 413    1.0             2013.500                                90.45606
#
#      X4 number of convenience stores
# 0                                 10
# 1                                  9
# 2                                  5
# 3                                  5
# 4                                  5
# ..                               ...
# 409                                0
# 410                                9
# 411                                7
# 412                                5
# 413                                9
#
# [414 rows x 4 columns]
#      const  X1 transaction date  X3 distance to the nearest MRT station  \
# 0      1.0             2012.917                                84.87882
# 1      1.0             2012.917                               306.59470
# 2      1.0             2013.583                               561.98450
# 3      1.0             2013.500                               561.98450
# 4      1.0             2012.833                               390.56840
# ..     ...                  ...                                     ...
# 409    1.0             2013.000                              4082.01500
# 410    1.0             2012.667                                90.45606
# 411    1.0             2013.250                               390.96960
# 412    1.0             2013.000                               104.81010
# 413    1.0             2013.500                                90.45606
#
#      X5 latitude
# 0       24.98298
# 1       24.98034
# 2       24.98746
# 3       24.98746
# 4       24.97937
# ..           ...
# 409     24.94155
# 410     24.97433
# 411     24.97923
# 412     24.96674
# 413     24.97433
#
# [414 rows x 4 columns]
#      const  X1 transaction date  X3 distance to the nearest MRT station  \
# 0      1.0             2012.917                                84.87882
# 1      1.0             2012.917                               306.59470
# 2      1.0             2013.583                               561.98450
# 3      1.0             2013.500                               561.98450
# 4      1.0             2012.833                               390.56840
# ..     ...                  ...                                     ...
# 409    1.0             2013.000                              4082.01500
# 410    1.0             2012.667                                90.45606
# 411    1.0             2013.250                               390.96960
# 412    1.0             2013.000                               104.81010
# 413    1.0             2013.500                                90.45606
#
#      X6 longitude
# 0       121.54024
# 1       121.53951
# 2       121.54391
# 3       121.54391
# 4       121.54245
# ..            ...
# 409     121.50381
# 410     121.54310
# 411     121.53986
# 412     121.54067
# 413     121.54310
#
# [414 rows x 4 columns]
#      const  X1 transaction date  X4 number of convenience stores  X5 latitude
# 0      1.0             2012.917                               10     24.98298
# 1      1.0             2012.917                                9     24.98034
# 2      1.0             2013.583                                5     24.98746
# 3      1.0             2013.500                                5     24.98746
# 4      1.0             2012.833                                5     24.97937
# ..     ...                  ...                              ...          ...
# 409    1.0             2013.000                                0     24.94155
# 410    1.0             2012.667                                9     24.97433
# 411    1.0             2013.250                                7     24.97923
# 412    1.0             2013.000                                5     24.96674
# 413    1.0             2013.500                                9     24.97433
#
# [414 rows x 4 columns]
#      const  X1 transaction date  X4 number of convenience stores  X6 longitude
# 0      1.0             2012.917                               10     121.54024
# 1      1.0             2012.917                                9     121.53951
# 2      1.0             2013.583                                5     121.54391
# 3      1.0             2013.500                                5     121.54391
# 4      1.0             2012.833                                5     121.54245
# ..     ...                  ...                              ...           ...
# 409    1.0             2013.000                                0     121.50381
# 410    1.0             2012.667                                9     121.54310
# 411    1.0             2013.250                                7     121.53986
# 412    1.0             2013.000                                5     121.54067
# 413    1.0             2013.500                                9     121.54310
#
# [414 rows x 4 columns]
#      const  X1 transaction date  X5 latitude  X6 longitude
# 0      1.0             2012.917     24.98298     121.54024
# 1      1.0             2012.917     24.98034     121.53951
# 2      1.0             2013.583     24.98746     121.54391
# 3      1.0             2013.500     24.98746     121.54391
# 4      1.0             2012.833     24.97937     121.54245
# ..     ...                  ...          ...           ...
# 409    1.0             2013.000     24.94155     121.50381
# 410    1.0             2012.667     24.97433     121.54310
# 411    1.0             2013.250     24.97923     121.53986
# 412    1.0             2013.000     24.96674     121.54067
# 413    1.0             2013.500     24.97433     121.54310
#
# [414 rows x 4 columns]
#      const  X2 house age  X3 distance to the nearest MRT station  \
# 0      1.0          32.0                                84.87882
# 1      1.0          19.5                               306.59470
# 2      1.0          13.3                               561.98450
# 3      1.0          13.3                               561.98450
# 4      1.0           5.0                               390.56840
# ..     ...           ...                                     ...
# 409    1.0          13.7                              4082.01500
# 410    1.0           5.6                                90.45606
# 411    1.0          18.8                               390.96960
# 412    1.0           8.1                               104.81010
# 413    1.0           6.5                                90.45606
#
#      X4 number of convenience stores
# 0                                 10
# 1                                  9
# 2                                  5
# 3                                  5
# 4                                  5
# ..                               ...
# 409                                0
# 410                                9
# 411                                7
# 412                                5
# 413                                9
#
# [414 rows x 4 columns]
#      const  X2 house age  X3 distance to the nearest MRT station  X5 latitude
# 0      1.0          32.0                                84.87882     24.98298
# 1      1.0          19.5                               306.59470     24.98034
# 2      1.0          13.3                               561.98450     24.98746
# 3      1.0          13.3                               561.98450     24.98746
# 4      1.0           5.0                               390.56840     24.97937
# ..     ...           ...                                     ...          ...
# 409    1.0          13.7                              4082.01500     24.94155
# 410    1.0           5.6                                90.45606     24.97433
# 411    1.0          18.8                               390.96960     24.97923
# 412    1.0           8.1                               104.81010     24.96674
# 413    1.0           6.5                                90.45606     24.97433
#
# [414 rows x 4 columns]
#      const  X2 house age  X3 distance to the nearest MRT station  X6 longitude
# 0      1.0          32.0                                84.87882     121.54024
# 1      1.0          19.5                               306.59470     121.53951
# 2      1.0          13.3                               561.98450     121.54391
# 3      1.0          13.3                               561.98450     121.54391
# 4      1.0           5.0                               390.56840     121.54245
# ..     ...           ...                                     ...           ...
# 409    1.0          13.7                              4082.01500     121.50381
# 410    1.0           5.6                                90.45606     121.54310
# 411    1.0          18.8                               390.96960     121.53986
# 412    1.0           8.1                               104.81010     121.54067
# 413    1.0           6.5                                90.45606     121.54310
#
# [414 rows x 4 columns]
#      const  X2 house age  X4 number of convenience stores  X5 latitude
# 0      1.0          32.0                               10     24.98298
# 1      1.0          19.5                                9     24.98034
# 2      1.0          13.3                                5     24.98746
# 3      1.0          13.3                                5     24.98746
# 4      1.0           5.0                                5     24.97937
# ..     ...           ...                              ...          ...
# 409    1.0          13.7                                0     24.94155
# 410    1.0           5.6                                9     24.97433
# 411    1.0          18.8                                7     24.97923
# 412    1.0           8.1                                5     24.96674
# 413    1.0           6.5                                9     24.97433
#
# [414 rows x 4 columns]
#      const  X2 house age  X4 number of convenience stores  X6 longitude
# 0      1.0          32.0                               10     121.54024
# 1      1.0          19.5                                9     121.53951
# 2      1.0          13.3                                5     121.54391
# 3      1.0          13.3                                5     121.54391
# 4      1.0           5.0                                5     121.54245
# ..     ...           ...                              ...           ...
# 409    1.0          13.7                                0     121.50381
# 410    1.0           5.6                                9     121.54310
# 411    1.0          18.8                                7     121.53986
# 412    1.0           8.1                                5     121.54067
# 413    1.0           6.5                                9     121.54310
#
# [414 rows x 4 columns]
#      const  X2 house age  X5 latitude  X6 longitude
# 0      1.0          32.0     24.98298     121.54024
# 1      1.0          19.5     24.98034     121.53951
# 2      1.0          13.3     24.98746     121.54391
# 3      1.0          13.3     24.98746     121.54391
# 4      1.0           5.0     24.97937     121.54245
# ..     ...           ...          ...           ...
# 409    1.0          13.7     24.94155     121.50381
# 410    1.0           5.6     24.97433     121.54310
# 411    1.0          18.8     24.97923     121.53986
# 412    1.0           8.1     24.96674     121.54067
# 413    1.0           6.5     24.97433     121.54310
#
# [414 rows x 4 columns]
#      const  X3 distance to the nearest MRT station  \
# 0      1.0                                84.87882
# 1      1.0                               306.59470
# 2      1.0                               561.98450
# 3      1.0                               561.98450
# 4      1.0                               390.56840
# ..     ...                                     ...
# 409    1.0                              4082.01500
# 410    1.0                                90.45606
# 411    1.0                               390.96960
# 412    1.0                               104.81010
# 413    1.0                                90.45606
#
#      X4 number of convenience stores  X5 latitude
# 0                                 10     24.98298
# 1                                  9     24.98034
# 2                                  5     24.98746
# 3                                  5     24.98746
# 4                                  5     24.97937
# ..                               ...          ...
# 409                                0     24.94155
# 410                                9     24.97433
# 411                                7     24.97923
# 412                                5     24.96674
# 413                                9     24.97433
#
# [414 rows x 4 columns]
#      const  X3 distance to the nearest MRT station  \
# 0      1.0                                84.87882
# 1      1.0                               306.59470
# 2      1.0                               561.98450
# 3      1.0                               561.98450
# 4      1.0                               390.56840
# ..     ...                                     ...
# 409    1.0                              4082.01500
# 410    1.0                                90.45606
# 411    1.0                               390.96960
# 412    1.0                               104.81010
# 413    1.0                                90.45606
#
#      X4 number of convenience stores  X6 longitude
# 0                                 10     121.54024
# 1                                  9     121.53951
# 2                                  5     121.54391
# 3                                  5     121.54391
# 4                                  5     121.54245
# ..                               ...           ...
# 409                                0     121.50381
# 410                                9     121.54310
# 411                                7     121.53986
# 412                                5     121.54067
# 413                                9     121.54310
#
# [414 rows x 4 columns]
#      const  X3 distance to the nearest MRT station  X5 latitude  X6 longitude
# 0      1.0                                84.87882     24.98298     121.54024
# 1      1.0                               306.59470     24.98034     121.53951
# 2      1.0                               561.98450     24.98746     121.54391
# 3      1.0                               561.98450     24.98746     121.54391
# 4      1.0                               390.56840     24.97937     121.54245
# ..     ...                                     ...          ...           ...
# 409    1.0                              4082.01500     24.94155     121.50381
# 410    1.0                                90.45606     24.97433     121.54310
# 411    1.0                               390.96960     24.97923     121.53986
# 412    1.0                               104.81010     24.96674     121.54067
# 413    1.0                                90.45606     24.97433     121.54310
#
# [414 rows x 4 columns]
#      const  X4 number of convenience stores  X5 latitude  X6 longitude
# 0      1.0                               10     24.98298     121.54024
# 1      1.0                                9     24.98034     121.53951
# 2      1.0                                5     24.98746     121.54391
# 3      1.0                                5     24.98746     121.54391
# 4      1.0                                5     24.97937     121.54245
# ..     ...                              ...          ...           ...
# 409    1.0                                0     24.94155     121.50381
# 410    1.0                                9     24.97433     121.54310
# 411    1.0                                7     24.97923     121.53986
# 412    1.0                                5     24.96674     121.54067
# 413    1.0                                9     24.97433     121.54310
#
# [414 rows x 4 columns]
#      const  X1 transaction date  X2 house age  \
# 0      1.0             2012.917          32.0
# 1      1.0             2012.917          19.5
# 2      1.0             2013.583          13.3
# 3      1.0             2013.500          13.3
# 4      1.0             2012.833           5.0
# ..     ...                  ...           ...
# 409    1.0             2013.000          13.7
# 410    1.0             2012.667           5.6
# 411    1.0             2013.250          18.8
# 412    1.0             2013.000           8.1
# 413    1.0             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# 4                                 390.56840                                5
# ..                                      ...                              ...
# 409                              4082.01500                                0
# 410                                90.45606                                9
# 411                               390.96960                                7
# 412                               104.81010                                5
# 413                                90.45606                                9
#
# [414 rows x 5 columns]
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
#      const  X1 transaction date  X2 house age  \
# 0      1.0             2012.917          32.0
# 1      1.0             2012.917          19.5
# 2      1.0             2013.583          13.3
# 3      1.0             2013.500          13.3
# 4      1.0             2012.833           5.0
# ..     ...                  ...           ...
# 409    1.0             2013.000          13.7
# 410    1.0             2012.667           5.6
# 411    1.0             2013.250          18.8
# 412    1.0             2013.000           8.1
# 413    1.0             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X5 latitude
# 0                                  84.87882     24.98298
# 1                                 306.59470     24.98034
# 2                                 561.98450     24.98746
# 3                                 561.98450     24.98746
# 4                                 390.56840     24.97937
# ..                                      ...          ...
# 409                              4082.01500     24.94155
# 410                                90.45606     24.97433
# 411                               390.96960     24.97923
# 412                               104.81010     24.96674
# 413                                90.45606     24.97433
#
# [414 rows x 5 columns]
#      const  X1 transaction date  X2 house age  \
# 0      1.0             2012.917          32.0
# 1      1.0             2012.917          19.5
# 2      1.0             2013.583          13.3
# 3      1.0             2013.500          13.3
# 4      1.0             2012.833           5.0
# ..     ...                  ...           ...
# 409    1.0             2013.000          13.7
# 410    1.0             2012.667           5.6
# 411    1.0             2013.250          18.8
# 412    1.0             2013.000           8.1
# 413    1.0             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X6 longitude
# 0                                  84.87882     121.54024
# 1                                 306.59470     121.53951
# 2                                 561.98450     121.54391
# 3                                 561.98450     121.54391
# 4                                 390.56840     121.54245
# ..                                      ...           ...
# 409                              4082.01500     121.50381
# 410                                90.45606     121.54310
# 411                               390.96960     121.53986
# 412                               104.81010     121.54067
# 413                                90.45606     121.54310
#
# [414 rows x 5 columns]
#      const  X1 transaction date  X2 house age  \
# 0      1.0             2012.917          32.0
# 1      1.0             2012.917          19.5
# 2      1.0             2013.583          13.3
# 3      1.0             2013.500          13.3
# 4      1.0             2012.833           5.0
# ...
# 0      1.0             2012.917          32.0
# 1      1.0             2012.917          19.5
# 2      1.0             2013.583          13.3
# 3      1.0             2013.500          13.3
# 4      1.0             2012.833           5.0
# ..     ...                  ...           ...
# 409    1.0             2013.000          13.7
# 410    1.0             2012.667           5.6
# 411    1.0             2013.250          18.8
# 412    1.0             2013.000           8.1
# 413    1.0             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# 4                                 390.56840                                5
# ..                                      ...                              ...
# 409                              4082.01500                                0
# 410                                90.45606                                9
# 411                               390.96960                                7
# 412                               104.81010                                5
# 413                                90.45606                                9
#
#      X6 longitude
# 0       121.54024
# 1       121.53951
# 2       121.54391
# 3       121.54391
# 4       121.54245
# ..            ...
# 409     121.50381
# 410     121.54310
# 411     121.53986
# 412     121.54067
# 413     121.54310
#
# [414 rows x 6 columns]
#      const  X1 transaction date  X2 house age  \
# 0      1.0             2012.917          32.0
# 1      1.0             2012.917          19.5
# 2      1.0             2013.583          13.3
# 3      1.0             2013.500          13.3
# 4      1.0             2012.833           5.0
# ..     ...                  ...           ...
# 409    1.0             2013.000          13.7
# 410    1.0             2012.667           5.6
# 411    1.0             2013.250          18.8
# 412    1.0             2013.000           8.1
# 413    1.0             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X5 latitude  X6 longitude
# 0                                  84.87882     24.98298     121.54024
# 1                                 306.59470     24.98034     121.53951
# 2                                 561.98450     24.98746     121.54391
# 3                                 561.98450     24.98746     121.54391
# 4                                 390.56840     24.97937     121.54245
# ..                                      ...          ...           ...
# 409                              4082.01500     24.94155     121.50381
# 410                                90.45606     24.97433     121.54310
# 411                               390.96960     24.97923     121.53986
# 412                               104.81010     24.96674     121.54067
# 413                                90.45606     24.97433     121.54310
#
# [414 rows x 6 columns]
#      const  X1 transaction date  X2 house age  \
# 0      1.0             2012.917          32.0
# 1      1.0             2012.917          19.5
# 2      1.0             2013.583          13.3
# 3      1.0             2013.500          13.3
# 4      1.0             2012.833           5.0
# ..     ...                  ...           ...
# 409    1.0             2013.000          13.7
# 410    1.0             2012.667           5.6
# 411    1.0             2013.250          18.8
# 412    1.0             2013.000           8.1
# 413    1.0             2013.500           6.5
#
#      X4 number of convenience stores  X5 latitude  X6 longitude
# 0                                 10     24.98298     121.54024
# 1                                  9     24.98034     121.53951
# 2                                  5     24.98746     121.54391
# 3                                  5     24.98746     121.54391
# 4                                  5     24.97937     121.54245
# ..                               ...          ...           ...
# 409                                0     24.94155     121.50381
# 410                                9     24.97433     121.54310
# 411                                7     24.97923     121.53986
# 412                                5     24.96674     121.54067
# 413                                9     24.97433     121.54310
#
# [414 rows x 6 columns]
#      const  X1 transaction date  X3 distance to the nearest MRT station  \
# 0      1.0             2012.917                                84.87882
# 1      1.0             2012.917                               306.59470
# 2      1.0             2013.583                               561.98450
# 3      1.0             2013.500                               561.98450
# 4      1.0             2012.833                               390.56840
# ..     ...                  ...                                     ...
# 409    1.0             2013.000                              4082.01500
# 410    1.0             2012.667                                90.45606
# 411    1.0             2013.250                               390.96960
# 412    1.0             2013.000                               104.81010
# 413    1.0             2013.500                                90.45606
#
#      X4 number of convenience stores  X5 latitude  X6 longitude
# 0                                 10     24.98298     121.54024
# 1                                  9     24.98034     121.53951
# 2                                  5     24.98746     121.54391
# 3                                  5     24.98746     121.54391
# 4                                  5     24.97937     121.54245
# ..                               ...          ...           ...
# 409                                0     24.94155     121.50381
# 410                                9     24.97433     121.54310
# 411                                7     24.97923     121.53986
# 412                                5     24.96674     121.54067
# 413                                9     24.97433     121.54310
#
# [414 rows x 6 columns]
#      const  X2 house age  X3 distance to the nearest MRT station  \
# 0      1.0          32.0                                84.87882
# 1      1.0          19.5                               306.59470
# 2      1.0          13.3                               561.98450
# 3      1.0          13.3                               561.98450
# 4      1.0           5.0                               390.56840
# ..     ...           ...                                     ...
# 409    1.0          13.7                              4082.01500
# 410    1.0           5.6                                90.45606
# 411    1.0          18.8                               390.96960
# 412    1.0           8.1                               104.81010
# 413    1.0           6.5                                90.45606
#
#      X4 number of convenience stores  X5 latitude  X6 longitude
# 0                                 10     24.98298     121.54024
# 1                                  9     24.98034     121.53951
# 2                                  5     24.98746     121.54391
# 3                                  5     24.98746     121.54391
# 4                                  5     24.97937     121.54245
# ..                               ...          ...           ...
# 409                                0     24.94155     121.50381
# 410                                9     24.97433     121.54310
# 411                                7     24.97923     121.53986
# 412                                5     24.96674     121.54067
# 413                                9     24.97433     121.54310
#
# [414 rows x 6 columns]
#      const  X1 transaction date  X2 house age  \
# 0      1.0             2012.917          32.0
# 1      1.0             2012.917          19.5
# 2      1.0             2013.583          13.3
# 3      1.0             2013.500          13.3
# 4      1.0             2012.833           5.0
# ..     ...                  ...           ...
# 409    1.0             2013.000          13.7
# 410    1.0             2012.667           5.6
# 411    1.0             2013.250          18.8
# 412    1.0             2013.000           8.1
# 413    1.0             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# 4                                 390.56840                                5
# ..                                      ...                              ...
# 409                              4082.01500                                0
# 410                                90.45606                                9
# 411                               390.96960                                7
# 412                               104.81010                                5
# 413                                90.45606                                9
#
#      X5 latitude  X6 longitude
# 0       24.98298     121.54024
# 1       24.98034     121.53951
# 2       24.98746     121.54391
# 3       24.98746     121.54391
# 4       24.97937     121.54245
# ..           ...           ...
# 409     24.94155     121.50381
# 410     24.97433     121.54310
# 411     24.97923     121.53986
# 412     24.96674     121.54067
# 413     24.97433     121.54310
#
# [414 rows x 7 columns]
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /var/folders/j1/rssdx9h148g0ptj4pj02c_0m0000gn/T/ipykernel_15658/1220570714.py in <module>
# ----> 1 problem5()
#
# /var/folders/j1/rssdx9h148g0ptj4pj02c_0m0000gn/T/ipykernel_15658/2969767840.py in problem5()
#      24     a = time.time()
#      25     #svd
# ---> 26     ols(temp_X, y)
#      27     b = time.time()
#      28
#
# /var/folders/j1/rssdx9h148g0ptj4pj02c_0m0000gn/T/ipykernel_15658/4256419172.py in ols(X, y)
#      13     Xnew = np.vstack((X,x0)).T
#      14     #putting values to make B
# ---> 15     B = np.linalg.inv(Xnew.T@Xnew)@Xnew.T@y
#      16
#      17     return B
#
# <__array_function__ internals> in inv(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/numpy/linalg/linalg.py in inv(a)
#     543     signature = 'D->D' if isComplexType(t) else 'd->d'
#     544     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 545     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     546     return wrap(ainv.astype(result_t, copy=False))
#     547
#
# ~/opt/anaconda3/lib/python3.9/site-packages/numpy/linalg/linalg.py in _raise_linalgerror_singular(err, flag)
#      86
#      87 def _raise_linalgerror_singular(err, flag):
# ---> 88     raise LinAlgError("Singular matrix")
#      89
#      90 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix

# %% [markdown]
# ## Problem 6
# Use the file **realestate.csv** and the Python Example on page 4 as a template for constructing **y** and $X$ and calculating model AIC and BIC.
# For the dependent variable, use **house price of unit area**.
# For the independent variables, use **distance to the nearest MRT station**, **number of convenience stores**, **latitude**, and **longitude**.
#
# Find the model that has the lowest AIC and the model that has the lowest BIC. Are they the same model? Print the features of the model with the lowest AIC as a list.

# %% [markdown]
# ## Problem 7
# Use Ridge and Lasso Regression to model **house price of unit area** from the file **realestate.csv**.
# Before fitting each model, run a GridSearch on $\alpha$ to find the optimal value.
# Then use the optimal $\alpha$ to fit the model.
# Once you have fit the model, you can use the **score** method to get $R^2$.
# Print $R^2$ for each model as a tuple.
# How do these models compare to the models in problem 6?
